# %%
import numpy as np
import pandas as pd

# %%
df_13f_2023q1 = pd.read_csv('../data/SEC/sec-form13f-2023q1/INFOTABLE.tsv', delimiter='\t')
# Out:
# /var/folders/n5/bkphn15s0kzc1lsr8x64v8y00000gn/T/ipykernel_4950/675598512.py:1: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_13f_2023q1 = pd.read_csv('../data/SEC/sec-form13f-2023q1/INFOTABLE.tsv', delimiter='\t')

# %%
df_13f_2023q1
# Out:
#              ACCESSION_NUMBER  INFOTABLE_SK           NAMEOFISSUER  \
# 0        0001971024-23-000012      84565983  VANGUARD BD INDEX FDS
# 1        0001971024-23-000012      84565984  VANGUARD BD INDEX FDS
# 2        0001971024-23-000012      84565985     VANGUARD INDEX FDS
# 3        0001971024-23-000012      84565986     VANGUARD INDEX FDS
# 4        0001971024-23-000012      84565987     VANGUARD INDEX FDS
# ...                       ...           ...                    ...
# 2786012  0001297731-23-000001      89044714           Prologis Inc
# 2786013  0001297731-23-000001      89044715         Public Storage
# 2786014  0001297731-23-000001      89044716      RLJ Lodging Trust
# 2786015  0001297731-23-000001      89044717     Realty Income Corp
# 2786016  0001297731-23-000001      89044718   SL Green Realty Corp
#
#             TITLEOFCLASS      CUSIP FIGI     VALUE  SSHPRNAMT SSHPRNAMTTYPE  \
# 0         SHORT TRM BOND  921937827  NaN    479354       5782            SH
# ...

# %%
metadata = pd.read_json('../data/SEC/sec-form13f-2023q1/FORM13F_metadata.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 metadata = pd.read_json('../data/SEC/sec-form13f-2023q1/FORM13F_metadata.json')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/json/_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
# ...
